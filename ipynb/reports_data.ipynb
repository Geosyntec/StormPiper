# %% [markdown]
# # Spatial Data for Reporting

# %%
import requests
import pandas as pd
import geopandas as gp
import ee
import json

# %% [markdown]
# Helper functions for querying arcgis REST api

# %%
def get_geojson_as_json(base_url, path, outFields=None):
    if outFields is None:
        outFields = '*'
    elif isinstance(outFields, list):
        outFields = ','.join(outFields)
    url = f"{base_url}{path}/query?where=1%3D1&outFields={outFields}&f=geojson"
    response = requests.get(url)
    geojson = json.loads(response.text)
    return geojson

def get_geojson_as_gp(base_url, path, outFields=None):
    if outFields is None:
        outFields = '*'
    elif isinstance(outFields, list):
        outFields = ','.join(outFields)
    url = f"{base_url}{path}/query?where=1%3D1&outFields={outFields}&f=geojson"
    df = gp.read_file(url, driver="GeoJSON")
    return df

# %% [markdown]
# Get subbasins

# %%
def gdf_to_ee(gdf):

    # Initialize an empty list to store features
    features = []

    # Iterate over each row in the GeoPandas DataFrame
    for index, row in gdf.iterrows():

        # Create a new Earth Engine feature from the row's geometry and properties
        feature = ee.Feature(ee.Geometry(row['geometry']), row.to_dict())

        # Append the feature to the list of features
        features.append(feature)

    # Create a new Earth Engine FeatureCollection from the list of features
    fc = ee.FeatureCollection(features)
    return(fc)

# %%
#start with subbasins

base_url = "https://gis.cityoftacoma.org/arcgis/rest/services/"
subbasins_path = "ES/SurfacewaterNetwork/MapServer/41" 
subbasins = get_geojson_as_gp(base_url,subbasins_path,outFields = ['BASINNAME','SUBBASIN'])
subbasins_geojson = get_geojson_as_json(base_url,subbasins_path)
subbasins.head()
# Out:
#           BASINNAME SUBBASIN  \
# 0    WESTERN SLOPES    WS_03
# 1    WESTERN SLOPES    WS_01
# 2       FLETT CREEK    FL_03
# 3         TIDEFLATS    TF_01
# 4  NORTHEAST TACOMA    NE_03
#
#                                             geometry
# 0  POLYGON ((-122.52683 47.25504, -122.52698 47.2...
# 1  POLYGON ((-122.51714 47.27441, -122.51758 47.2...
# 2  POLYGON ((-122.47503 47.20173, -122.47490 47.2...
# 3  POLYGON ((-122.42198 47.26224, -122.42210 47.2...
# 4  POLYGON ((-122.38348 47.29529, -122.38389 47.2...

# %% [markdown]
# # Land Use
#
# % Commercial
#
# % Industrial
#
# % Roads
#
# % Single Family Residential
#
# % Multifamily Residential
#
# % Parks & Undeveloped Land

# %%
#ee.Initialize()
#!{'earthengine authenticate'}

# %%
# construct a FeatureCollection object from the json object
#fc = ee.FeatureCollection(subbasins)

# %%
# Get Land use layer 

landuse_path = "General/LandUseDesignations/MapServer/0" 
landuse = get_geojson_as_gp(base_url,landuse_path)
landuse.head()
# Out:
#    OBJECTID       LandUseDesignation MixedUseCenter CreatedBy   CreatedDate  \
# 0         1  Neighborhood Commercial                      GIS  1.589440e+12
# 1         2  Neighborhood Commercial                      GIS  1.589440e+12
# 2         3  Neighborhood Commercial                      GIS  1.589440e+12
# 3         4  Neighborhood Commercial                      GIS  1.589440e+12
# 4         5  Neighborhood Commercial                      GIS  1.589440e+12
#
#   LastEditor     LastEdited                                GlobalID  \
# 0     JSHELL  1646899200000  {4DBA624E-52CB-4DD2-8EC3-F53406B03BDD}
# 1     JSHELL  1646899200000  {79CEDC72-94D6-48F1-8ED9-D61439CDE7BC}
# 2     JSHELL  1646812800000  {FC67B342-7357-4B29-9E8A-A6F56DCA69DF}
# 3     JSHELL  1646899200000  {A1650268-55B7-4B9F-8ABF-B57830203625}
# 4     JSHELL  1643356800000  {225DAC6B-6459-460E-8391-1337EBB7D345}
#
#    SHAPE.STArea()  SHAPE.STLength()  \
# 0   780055.492840       6999.852238
# 1   392833.682215       2976.539156
# 2   664591.050547       6102.065086
# 3   161966.320290       1813.323761
# 4   130461.335699       1519.301520
#
#                                             geometry
# 0  POLYGON ((-122.51593 47.25542, -122.51596 47.2...
# 1  POLYGON ((-122.49433 47.25599, -122.49433 47.2...
# 2  POLYGON ((-122.45586 47.25730, -122.45598 47.2...
# 3  POLYGON ((-122.51508 47.26058, -122.51572 47.2...
# 4  POLYGON ((-122.45770 47.26217, -122.45759 47.2...

# %%
def overlay_and_summarize(x,by_x,by_y="SUBBASIN",y=subbasins): 
    x = x.to_crs('EPSG:3857')
    y = y.to_crs('EPSG:3857')
    shp_tmp = y.overlay(x, how='intersection')

    shp_tmp['intersected_area'] = shp_tmp.area
    shp_tmp = shp_tmp[[by_x,by_y,'intersected_area']]
    summary = shp_tmp.groupby([by_y,by_x]).sum()
    summary['percent'] = summary['intersected_area'] / summary.groupby(by_y)["intersected_area"].transform('sum')
    return(summary)

# %%
lu_summary = overlay_and_summarize(landuse,'LandUseDesignation')
lu_summary.style.format({'percent': '{:.2%}'.format})
lu_summary.head
# Out:
# <bound method NDFrame.head of                                       intersected_area   percent
# SUBBASIN LandUseDesignation
# FL_01    Crossroads Mixed-Use Center      3.664704e+03  0.000832
#          General Commercial               1.859721e+05  0.042233
#          Low-Scale Residential            2.572084e+06  0.584108
#          Major Institutional Campus       5.505233e+05  0.125021
#          Mid-Scale Residential            5.342479e+05  0.121325
# ...                                                ...       ...
# WS_04    Low-Scale Residential            3.308445e+06  0.682731
#          Mid-Scale Residential            6.819940e+05  0.140736
#          Neighborhood Commercial          9.638384e+03  0.001989
#          Parks and Open Space             4.485093e+05  0.092554
#          Shoreline                        3.679924e+05  0.075939
#
# [384 rows x 2 columns]>

# %%
lu_summary
# Out:
#                                       intersected_area   percent
# SUBBASIN LandUseDesignation
# FL_01    Crossroads Mixed-Use Center      3.664704e+03  0.000832
#          General Commercial               1.859721e+05  0.042233
#          Low-Scale Residential            2.572084e+06  0.584108
#          Major Institutional Campus       5.505233e+05  0.125021
#          Mid-Scale Residential            5.342479e+05  0.121325
# ...                                                ...       ...
# WS_04    Low-Scale Residential            3.308445e+06  0.682731
#          Mid-Scale Residential            6.819940e+05  0.140736
#          Neighborhood Commercial          9.638384e+03  0.001989
#          Parks and Open Space             4.485093e+05  0.092554
#          Shoreline                        3.679924e+05  0.075939
#
# [384 rows x 2 columns]

# %%
#lu_summary.pivot(index = 0, columns='LandUseDesignation', values='percent')

lu_summary_df = lu_summary.reset_index()
pivot_table = lu_summary_df.pivot(index='SUBBASIN', columns='LandUseDesignation', values='percent')
pivot_table

# %%
pivot_table.to_csv('exported_data/landuse.csv')

# %% [markdown]
# # Land Cover
#
# % Forest
# % Pasture
# %Landscape
# %Effective Impervious Surface

# %%
import ee 
ee.Initialize()
landcover_layer = ee.Image("projects/ee-swhm/assets/production_layers/HSPF_Land_Cover_Type") 
fc = ee.FeatureCollection(subbasins_geojson)

# %%
# Create an image with pixel area and land cover layer
img = ee.Image.pixelArea().addBands(landcover_layer)

# Filter the watersheds table by geometry
geometry =     ee.Geometry.Polygon(
        [[[-122.51117300651649, 47.27135819591651],
          [-122.51117300651649, 47.216352555552646],
          [-122.45006155632117, 47.216352555552646],
          [-122.45006155632117, 47.27135819591651]]]);

# %%
# Define the summarize_groups function
def summarize_groups(feature):
    return feature.select(['SUBBASIN','groups'],retainGeometry=False)
# Reduce the image by watersheds and summarize the groups
lc_summary = img.reduceRegions(
    collection=fc,
    reducer=ee.Reducer.sum().group(
        groupField=1,
        groupName='class value'
    ),
    scale=10
).map(summarize_groups)

data = lc_summary.getInfo()
import json



# Access properties of each feature
for feature in data['features']:
    groups = feature['properties']['groups']
    
    print(groups)
# Print the land cover summary
# Out:
# [{'class value': 0, 'sum': 403702.4926592059}, {'class value': 1, 'sum': 552408.9458083506}, {'class value': 2, 'sum': 517293.7250080183}, {'class value': 3, 'sum': 44620.25246710685}, {'class value': 4, 'sum': 452708.64505468635}, {'class value': 5, 'sum': 794207.7051418227}]
# [{'class value': 0, 'sum': 1805662.2313714137}, {'class value': 1, 'sum': 334657.15909343056}, {'class value': 2, 'sum': 293116.05679393077}, {'class value': 3, 'sum': 43867.26018530151}, {'class value': 4, 'sum': 232029.68932372457}, {'class value': 5, 'sum': 386715.0641378965}]
# [{'class value': 0, 'sum': 750034.2561410052}, {'class value': 1, 'sum': 1261949.1943272313}, {'class value': 2, 'sum': 1431501.4796279925}, {'class value': 3, 'sum': 8193.493944833794}, {'class value': 4, 'sum': 1063263.2957162901}, {'class value': 5, 'sum': 2349192.3468385586}]
# [{'class value': 0, 'sum': 5131.471637860466}, {'class value': 1, 'sum': 264080.1105069329}, {'class value': 2, 'sum': 52216.81205303715}, {'class value': 3, 'sum': 91419.08554349409}, {'class value': 4, 'sum': 197030.09100455485}, {'class value': 5, 'sum': 438144.7950711118}]
# [{'class value': 0, 'sum': 1158250.0650290747}, {'class value': 1, 'sum': 565559.8733041794}, {'class value': 2, 'sum': 1001178.7363055953}, {'class value': 3, 'sum': 60787.184197429604}, {'class value': 4, 'sum': 568748.691436887}, {'class value': 5, 'sum': 603551.9897060025}]
# [{'class value': 0, 'sum': 24766.298512627098}, {'class value': 1, 'sum': 69576.979967424}, {'class value': 2, 'sum': 13794.295655074775}, {'class value': 3, 'sum': 18866.646887895167}, {'class value': 4, 'sum': 118301.12535591878}, {'class value': 5, 'sum': 1254961.6673800896}]
# [{'class value': 0, 'sum': 578494.0238871551}, {'class value': 1, 'sum': 96123.90739081887}, {'class value': 2, 'sum': 259428.5718776028}, {'class value': 3, 'sum': 20912.189102831067}, {'class value': 4, 'sum': 134996.3357581045}, {'class value': 5, 'sum': 150660.91596099266}]
# [{'class value': 0, 'sum': 172851.04519210517}, {'class value': 1, 'sum': 308805.3998828066}, {'class value': 2, 'sum': 216522.14505543426}, {'class value': 3, 'sum': 26341.84455925437}, {'class value': 4, 'sum': 227442.51789170798}, {'class value': 5, 'sum': 457110.8936356186}]
# [{'class value': 0, 'sum': 408091.04809450655}, {'class value': 1, 'sum': 567238.4034484864}, {'class value': 2, 'sum': 673345.318188895}, {'class value': 3, 'sum': 401.1663771984624}, {'class value': 4, 'sum': 369103.8819461897}, {'class value': 5, 'sum': 792174.3631130747}]
# [{'class value': 0, 'sum': 270753.66958151426}, {'class value': 1, 'sum': 193143.83852269786}, {'class value': 2, 'sum': 127149.34932239009}, {'class value': 3, 'sum': 13454.285641449578}, {'class value': 4, 'sum': 156566.01623391543}, {'class value': 5, 'sum': 184480.5550943711}]
# [{'class value': 0, 'sum': 24538.54188498702}, {'class value': 1, 'sum': 70946.94704556932}, {'class value': 2, 'sum': 47095.31320232317}, {'class value': 3, 'sum': 9263.938355449603}, {'class value': 4, 'sum': 58016.6913721122}, {'class value': 5, 'sum': 75276.69011311253}]
# [{'class value': 0, 'sum': 145809.6600750792}, {'class value': 1, 'sum': 383279.0218344296}, {'class value': 2, 'sum': 231390.08511906042}, {'class value': 4, 'sum': 292148.86851184315}, {'class value': 5, 'sum': 642300.0477578256}]
# [{'class value': 0, 'sum': 32975.92758899764}, {'class value': 1, 'sum': 89151.71350013881}, {'class value': 2, 'sum': 55911.67245193182}, {'class value': 4, 'sum': 96200.94375059838}, {'class value': 5, 'sum': 103396.03306923657}]
# [{'class value': 0, 'sum': 144714.8652090035}, {'class value': 1, 'sum': 564262.1596540271}, {'class value': 2, 'sum': 379107.3190374933}, {'class value': 4, 'sum': 414873.35596896894}, {'class value': 5, 'sum': 567642.6378510724}]
# [{'class value': 0, 'sum': 285930.4150757135}, {'class value': 1, 'sum': 346794.17343630333}, {'class value': 2, 'sum': 659960.0344694251}, {'class value': 3, 'sum': 40781.69427977918}, {'class value': 4, 'sum': 391278.7256952622}, {'class value': 5, 'sum': 533377.7225557815}]
# [{'class value': 0, 'sum': 157930.64149741377}, {'class value': 1, 'sum': 204027.76320723005}, {'class value': 2, 'sum': 68982.74991081089}, {'class value': 3, 'sum': 8189.481432716517}, {'class value': 4, 'sum': 237913.3167388617}, {'class value': 5, 'sum': 373593.4549188948}]
# [{'class value': 0, 'sum': 1768656.0448832498}, {'class value': 1, 'sum': 752853.7509626797}, {'class value': 2, 'sum': 703697.5430864822}, {'class value': 3, 'sum': 24636.64610395244}, {'class value': 4, 'sum': 470786.89507694636}, {'class value': 5, 'sum': 833852.3660144584}]
# [{'class value': 0, 'sum': 226606.8910764507}, {'class value': 1, 'sum': 304709.90408241434}, {'class value': 2, 'sum': 463000.66189724783}, {'class value': 3, 'sum': 5501.3586349487305}, {'class value': 4, 'sum': 308809.8671539905}, {'class value': 5, 'sum': 709557.9376090857}]
# [{'class value': 0, 'sum': 204104.5562039244}, {'class value': 1, 'sum': 155257.7293171602}, {'class value': 2, 'sum': 218191.31713717594}, {'class value': 3, 'sum': 974.7669212490903}, {'class value': 4, 'sum': 159279.625752707}, {'class value': 5, 'sum': 185578.4234293918}]
# [{'class value': 0, 'sum': 409223.0495685354}, {'class value': 1, 'sum': 77660.14219165876}, {'class value': 2, 'sum': 87279.39491119384}, {'class value': 3, 'sum': 36107.500392569746}, {'class value': 4, 'sum': 53263.92905988505}, {'class value': 5, 'sum': 111422.0121078192}]
# [{'class value': 0, 'sum': 191512.21794747742}, {'class value': 1, 'sum': 547341.5720260617}, {'class value': 2, 'sum': 587402.4355640488}, {'class value': 3, 'sum': 1834.1005020141602}, {'class value': 4, 'sum': 306772.40801433503}, {'class value': 5, 'sum': 852743.3993708607}]
# [{'class value': 0, 'sum': 75595.63052323285}, {'class value': 1, 'sum': 242842.51394979446}, {'class value': 2, 'sum': 263847.1769595875}, {'class value': 4, 'sum': 153606.87395815382}, {'class value': 5, 'sum': 282837.8160042556}]
# [{'class value': 0, 'sum': 59834.61213211359}, {'class value': 1, 'sum': 452785.70923856867}, {'class value': 2, 'sum': 90277.76286348829}, {'class value': 3, 'sum': 3267.1425106272986}, {'class value': 4, 'sum': 590796.6987440819}, {'class value': 5, 'sum': 1137732.7468445725}]
# [{'class value': 0, 'sum': 337783.47184552957}, {'class value': 1, 'sum': 895461.1097433955}, {'class value': 2, 'sum': 677767.7174409745}, {'class value': 3, 'sum': 32140.958728924925}, {'class value': 4, 'sum': 725565.586231366}, {'class value': 5, 'sum': 1318833.0558860926}]
# [{'class value': 0, 'sum': 131695.90588582357}, {'class value': 1, 'sum': 317823.3866151396}, {'class value': 2, 'sum': 108296.69641726624}, {'class value': 3, 'sum': 6812.679614586923}, {'class value': 4, 'sum': 196080.14084098669}, {'class value': 5, 'sum': 1258799.5303853652}]
# [{'class value': 0, 'sum': 585633.0119937072}, {'class value': 1, 'sum': 948543.6271839514}, {'class value': 2, 'sum': 607402.0022232654}, {'class value': 3, 'sum': 2779.1105476528987}, {'class value': 4, 'sum': 980100.4683596448}, {'class value': 5, 'sum': 1118274.1827585264}]
# [{'class value': 0, 'sum': 19495.86014404296}, {'class value': 1, 'sum': 192564.25915093516}, {'class value': 2, 'sum': 233066.7529799218}, {'class value': 3, 'sum': 16037.152461900898}, {'class value': 4, 'sum': 8173.943796494428}, {'class value': 5, 'sum': 700484.2624320537}]
# [{'class value': 0, 'sum': 120863.34702298032}, {'class value': 1, 'sum': 103402.98942939911}, {'class value': 2, 'sum': 117844.33905861051}, {'class value': 3, 'sum': 6046.535224914551}, {'class value': 4, 'sum': 77916.29135242538}, {'class value': 5, 'sum': 262861.8644886092}]
# [{'class value': 1, 'sum': 7330.995172119141}, {'class value': 2, 'sum': 704.3007121366613}, {'class value': 3, 'sum': 8490.32980439429}, {'class value': 4, 'sum': 48028.361206533395}, {'class value': 5, 'sum': 153361.91168951883}]
# [{'class value': 0, 'sum': 106711.64465442733}, {'class value': 1, 'sum': 246094.90128484994}, {'class value': 2, 'sum': 250716.75160962262}, {'class value': 4, 'sum': 241747.4943452424}, {'class value': 5, 'sum': 384578.7061357385}]
# [{'class value': 0, 'sum': 193459.70095511046}, {'class value': 1, 'sum': 108595.22852570776}, {'class value': 2, 'sum': 145220.88890964285}, {'class value': 3, 'sum': 19030.859549279307}, {'class value': 4, 'sum': 138597.67167765295}, {'class value': 5, 'sum': 197384.3966948865}]
# [{'class value': 0, 'sum': 369974.4030119652}, {'class value': 1, 'sum': 518485.8886413575}, {'class value': 2, 'sum': 439778.9851830578}, {'class value': 3, 'sum': 78998.30651855469}, {'class value': 4, 'sum': 354406.18363309366}, {'class value': 5, 'sum': 681024.8133370497}]
# [{'class value': 0, 'sum': 190595.1887408388}, {'class value': 1, 'sum': 238590.67346616255}, {'class value': 2, 'sum': 436886.7947362561}, {'class value': 3, 'sum': 15256.032712719487}, {'class value': 4, 'sum': 27548.360778718838}, {'class value': 5, 'sum': 275604.6171603032}]
# [{'class value': 0, 'sum': 339.62547302246094}, {'class value': 1, 'sum': 47329.21194452024}, {'class value': 3, 'sum': 2178.4883252312156}, {'class value': 4, 'sum': 104198.96273576326}, {'class value': 5, 'sum': 431012.85243380663}]
# [{'class value': 0, 'sum': 190836.92352163268}, {'class value': 1, 'sum': 45144.82786563051}, {'class value': 2, 'sum': 70403.59492271276}, {'class value': 4, 'sum': 38340.078745194965}, {'class value': 5, 'sum': 55102.424573561715}]
# [{'class value': 0, 'sum': 359808.1309650496}, {'class value': 1, 'sum': 766905.2038571525}, {'class value': 2, 'sum': 454118.67444787046}, {'class value': 4, 'sum': 692191.3650198843}, {'class value': 5, 'sum': 1224229.1692125208}]
# [{'class value': 0, 'sum': 2527.461288511987}, {'class value': 1, 'sum': 89956.1625771915}, {'class value': 2, 'sum': 67.91226196289062}, {'class value': 3, 'sum': 12715.763869850305}, {'class value': 4, 'sum': 107863.06167315315}, {'class value': 5, 'sum': 269969.7540637743}]
# [{'class value': 0, 'sum': 498795.7244438919}, {'class value': 1, 'sum': 732818.8694352988}, {'class value': 2, 'sum': 471560.1662308338}, {'class value': 4, 'sum': 618405.1223083196}, {'class value': 5, 'sum': 1154656.445509401}]
# [{'class value': 0, 'sum': 665037.4609041098}, {'class value': 1, 'sum': 897317.0999066802}, {'class value': 2, 'sum': 1427675.739856285}, {'class value': 4, 'sum': 723227.6726930798}, {'class value': 5, 'sum': 1095695.226804007}]
# [{'class value': 0, 'sum': 49457.82470604392}, {'class value': 1, 'sum': 35562.80464169373}, {'class value': 2, 'sum': 38683.00921807383}, {'class value': 3, 'sum': 8481.374160826439}, {'class value': 4, 'sum': 31762.948471907075}, {'class value': 5, 'sum': 58128.2810590258}]
# [{'class value': 0, 'sum': 91203.08896942137}, {'class value': 1, 'sum': 323764.63023158035}, {'class value': 2, 'sum': 242567.4102604584}, {'class value': 4, 'sum': 274414.1701914169}, {'class value': 5, 'sum': 644627.6279905129}]
# [{'class value': 0, 'sum': 696040.1118219113}, {'class value': 1, 'sum': 627691.3973336013}, {'class value': 2, 'sum': 971162.1004406192}, {'class value': 4, 'sum': 407862.96360318083}, {'class value': 5, 'sum': 1122282.82354123}]
# [{'class value': 0, 'sum': 212803.44992894182}, {'class value': 1, 'sum': 36328.74133142206}, {'class value': 2, 'sum': 60595.47210041122}, {'class value': 4, 'sum': 42316.435754813414}, {'class value': 5, 'sum': 42857.110877990744}]
# [{'class value': 0, 'sum': 4219.779718496285}, {'class value': 1, 'sum': 811680.6706110036}, {'class value': 2, 'sum': 162073.27933756507}, {'class value': 3, 'sum': 97484.90547021598}, {'class value': 4, 'sum': 138062.88904798919}, {'class value': 5, 'sum': 934640.0329425894}]
# [{'class value': 0, 'sum': 97259.91158869134}, {'class value': 1, 'sum': 338644.7485462863}, {'class value': 2, 'sum': 196743.5411287493}, {'class value': 4, 'sum': 168691.13478884238}, {'class value': 5, 'sum': 443196.3040442073}]
# [{'class value': 0, 'sum': 62486.750523466224}, {'class value': 1, 'sum': 344683.4571641511}, {'class value': 2, 'sum': 124965.78910390817}, {'class value': 3, 'sum': 69337.16852031036}, {'class value': 4, 'sum': 360539.61716527}, {'class value': 5, 'sum': 2940504.454176808}]
# [{'class value': 0, 'sum': 112378.75604672899}, {'class value': 1, 'sum': 170144.41619041297}, {'class value': 2, 'sum': 105420.24990500657}, {'class value': 4, 'sum': 112156.67293560551}, {'class value': 5, 'sum': 335547.25387444586}]
# [{'class value': 0, 'sum': 763953.2504225788}, {'class value': 1, 'sum': 69676.97255503335}, {'class value': 2, 'sum': 176540.89543834006}, {'class value': 4, 'sum': 24185.322381292604}, {'class value': 5, 'sum': 44409.18806304932}]
# [{'class value': 0, 'sum': 168834.19223728552}, {'class value': 1, 'sum': 827788.5212095378}, {'class value': 2, 'sum': 342908.23867103714}, {'class value': 4, 'sum': 500484.6152789845}, {'class value': 5, 'sum': 860263.4241160672}]
# [{'class value': 0, 'sum': 325042.2350011789}, {'class value': 1, 'sum': 134205.57145457558}, {'class value': 2, 'sum': 225996.27709661747}, {'class value': 4, 'sum': 171459.5946232216}, {'class value': 5, 'sum': 134284.99231815708}]
# [{'class value': 0, 'sum': 260040.29933085723}, {'class value': 1, 'sum': 436856.6741849119}, {'class value': 2, 'sum': 898074.6326798685}, {'class value': 4, 'sum': 381373.85677945}, {'class value': 5, 'sum': 611582.1167669864}]
# [{'class value': 0, 'sum': 611344.5470809636}, {'class value': 1, 'sum': 947944.2043423828}, {'class value': 2, 'sum': 1293250.631013548}, {'class value': 4, 'sum': 933064.8934988885}, {'class value': 5, 'sum': 1315343.0453148033}]
# [{'class value': 0, 'sum': 34684.89385402903}, {'class value': 1, 'sum': 220629.6123565974}, {'class value': 2, 'sum': 236170.49902717743}, {'class value': 3, 'sum': 116013.29239663515}, {'class value': 4, 'sum': 107194.35630921011}, {'class value': 5, 'sum': 934244.7914150758}]
# [{'class value': 0, 'sum': 46014.58861978563}, {'class value': 1, 'sum': 151888.20119892195}, {'class value': 2, 'sum': 38104.65265963685}, {'class value': 4, 'sum': 66859.10585440844}, {'class value': 5, 'sum': 243553.6455058679}]
# [{'class value': 0, 'sum': 130725.72379123459}, {'class value': 1, 'sum': 756759.7729028733}, {'class value': 2, 'sum': 218341.42885915723}, {'class value': 4, 'sum': 479990.2941268919}, {'class value': 5, 'sum': 756004.536091853}]
# [{'class value': 0, 'sum': 791634.8799029482}, {'class value': 1, 'sum': 1217154.5621210146}, {'class value': 2, 'sum': 1107557.6641597082}, {'class value': 3, 'sum': 4188.626374398026}, {'class value': 4, 'sum': 1099992.8215072332}, {'class value': 5, 'sum': 1715178.778033509}]
# [{'class value': 0, 'sum': 74870.18450006223}, {'class value': 1, 'sum': 220668.25623315547}, {'class value': 2, 'sum': 82295.99635054644}, {'class value': 4, 'sum': 431617.365029309}, {'class value': 5, 'sum': 979017.2369808416}]
# [{'class value': 0, 'sum': 11565.282352641985}, {'class value': 1, 'sum': 117824.89798506197}, {'class value': 2, 'sum': 69088.46411503808}, {'class value': 3, 'sum': 3230.1961361754175}, {'class value': 4, 'sum': 125068.85448704142}, {'class value': 5, 'sum': 344163.9966232898}]
# [{'class value': 0, 'sum': 16216.938730307185}, {'class value': 1, 'sum': 115113.5125155281}, {'class value': 2, 'sum': 51688.092102110604}, {'class value': 3, 'sum': 271.1670960968616}, {'class value': 4, 'sum': 142303.06181903917}, {'class value': 5, 'sum': 296717.280043718}]
# [{'class value': 0, 'sum': 89756.29872355743}, {'class value': 1, 'sum': 83256.45552206601}, {'class value': 2, 'sum': 10530.51809464997}, {'class value': 3, 'sum': 6572.629269857965}, {'class value': 4, 'sum': 141630.55089727667}, {'class value': 5, 'sum': 336593.79594110243}]
# [{'class value': 0, 'sum': 136523.82024224979}, {'class value': 1, 'sum': 91358.0503928988}, {'class value': 2, 'sum': 79542.91121221804}, {'class value': 4, 'sum': 27483.387555948895}, {'class value': 5, 'sum': 171025.9678485646}]
# [{'class value': 0, 'sum': 1275309.2072551653}, {'class value': 1, 'sum': 133676.36066945392}, {'class value': 2, 'sum': 105327.24228826784}, {'class value': 3, 'sum': 41049.07849788293}, {'class value': 4, 'sum': 28700.05097425872}, {'class value': 5, 'sum': 200939.69972549137}]
# [{'class value': 0, 'sum': 690434.5563792812}, {'class value': 1, 'sum': 363456.82344222727}, {'class value': 2, 'sum': 579251.4169842288}, {'class value': 4, 'sum': 326123.67987228086}, {'class value': 5, 'sum': 595680.0984272077}]
# [{'class value': 0, 'sum': 66145.63297382431}, {'class value': 1, 'sum': 189397.93845711497}, {'class value': 2, 'sum': 96219.25015375472}, {'class value': 4, 'sum': 183861.34402597463}, {'class value': 5, 'sum': 291272.95519675466}]
# [{'class value': 0, 'sum': 342296.7354385675}, {'class value': 1, 'sum': 370448.07712489116}, {'class value': 2, 'sum': 406140.4946240294}, {'class value': 4, 'sum': 359960.30109073425}, {'class value': 5, 'sum': 551357.4129797244}]
# [{'class value': 0, 'sum': 1753.3568979300703}, {'class value': 1, 'sum': 131455.85047706153}, {'class value': 2, 'sum': 65743.42318695667}, {'class value': 3, 'sum': 11722.799520096121}, {'class value': 4, 'sum': 107870.07734099744}, {'class value': 5, 'sum': 1414221.2409883686}]
# [{'class value': 0, 'sum': 98011.7261458752}, {'class value': 1, 'sum': 93546.5673165116}, {'class value': 2, 'sum': 40622.635472256516}, {'class value': 3, 'sum': 14621.140655517578}, {'class value': 4, 'sum': 129835.8824823417}, {'class value': 5, 'sum': 244602.70583546965}]

# %%
data
# Out:
# {'type': 'FeatureCollection',
#  'columns': {},
#  'features': [{'type': 'Feature',
#    'geometry': None,
#    'id': '0',
#    'properties': {'SUBBASIN': 'WS_03',
#     'groups': [{'class value': 0, 'sum': 403702.4926592059},
#      {'class value': 1, 'sum': 552408.9458083506},
#      {'class value': 2, 'sum': 517293.7250080183},
#      {'class value': 3, 'sum': 44620.25246710685},
#      {'class value': 4, 'sum': 452708.64505468635},
#      {'class value': 5, 'sum': 794207.7051418227}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '1',
#    'properties': {'SUBBASIN': 'WS_01',
#     'groups': [{'class value': 0, 'sum': 1805662.2313714137},
#      {'class value': 1, 'sum': 334657.15909343056},
#      {'class value': 2, 'sum': 293116.05679393077},
#      {'class value': 3, 'sum': 43867.26018530151},
#      {'class value': 4, 'sum': 232029.68932372457},
#      {'class value': 5, 'sum': 386715.0641378965}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '2',
#    'properties': {'SUBBASIN': 'FL_03',
#     'groups': [{'class value': 0, 'sum': 750034.2561410052},
#      {'class value': 1, 'sum': 1261949.1943272313},
#      {'class value': 2, 'sum': 1431501.4796279925},
#      {'class value': 3, 'sum': 8193.493944833794},
#      {'class value': 4, 'sum': 1063263.2957162901},
#      {'class value': 5, 'sum': 2349192.3468385586}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '3',
#    'properties': {'SUBBASIN': 'TF_01',
#     'groups': [{'class value': 0, 'sum': 5131.471637860466},
#      {'class value': 1, 'sum': 264080.1105069329},
#      {'class value': 2, 'sum': 52216.81205303715},
#      {'class value': 3, 'sum': 91419.08554349409},
#      {'class value': 4, 'sum': 197030.09100455485},
#      {'class value': 5, 'sum': 438144.7950711118}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '4',
#    'properties': {'SUBBASIN': 'NE_03',
#     'groups': [{'class value': 0, 'sum': 1158250.0650290747},
#      {'class value': 1, 'sum': 565559.8733041794},
#      {'class value': 2, 'sum': 1001178.7363055953},
#      {'class value': 3, 'sum': 60787.184197429604},
#      {'class value': 4, 'sum': 568748.691436887},
#      {'class value': 5, 'sum': 603551.9897060025}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '5',
#    'properties': {'SUBBASIN': 'TF_02',
#     'groups': [{'class value': 0, 'sum': 24766.298512627098},
#      {'class value': 1, 'sum': 69576.979967424},
#      {'class value': 2, 'sum': 13794.295655074775},
#      {'class value': 3, 'sum': 18866.646887895167},
#      {'class value': 4, 'sum': 118301.12535591878},
#      {'class value': 5, 'sum': 1254961.6673800896}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '6',
#    'properties': {'SUBBASIN': 'NE_02',
#     'groups': [{'class value': 0, 'sum': 578494.0238871551},
#      {'class value': 1, 'sum': 96123.90739081887},
#      {'class value': 2, 'sum': 259428.5718776028},
#      {'class value': 3, 'sum': 20912.189102831067},
#      {'class value': 4, 'sum': 134996.3357581045},
#      {'class value': 5, 'sum': 150660.91596099266}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '7',
#    'properties': {'SUBBASIN': 'NT_03',
#     'groups': [{'class value': 0, 'sum': 172851.04519210517},
#      {'class value': 1, 'sum': 308805.3998828066},
#      {'class value': 2, 'sum': 216522.14505543426},
#      {'class value': 3, 'sum': 26341.84455925437},
#      {'class value': 4, 'sum': 227442.51789170798},
#      {'class value': 5, 'sum': 457110.8936356186}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '8',
#    'properties': {'SUBBASIN': 'LP_02',
#     'groups': [{'class value': 0, 'sum': 408091.04809450655},
#      {'class value': 1, 'sum': 567238.4034484864},
#      {'class value': 2, 'sum': 673345.318188895},
#      {'class value': 3, 'sum': 401.1663771984624},
#      {'class value': 4, 'sum': 369103.8819461897},
#      {'class value': 5, 'sum': 792174.3631130747}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '9',
#    'properties': {'SUBBASIN': 'WS_02',
#     'groups': [{'class value': 0, 'sum': 270753.66958151426},
#      {'class value': 1, 'sum': 193143.83852269786},
#      {'class value': 2, 'sum': 127149.34932239009},
#      {'class value': 3, 'sum': 13454.285641449578},
#      {'class value': 4, 'sum': 156566.01623391543},
#      {'class value': 5, 'sum': 184480.5550943711}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '10',
#    'properties': {'SUBBASIN': 'NT_08',
#     'groups': [{'class value': 0, 'sum': 24538.54188498702},
#      {'class value': 1, 'sum': 70946.94704556932},
#      {'class value': 2, 'sum': 47095.31320232317},
#      {'class value': 3, 'sum': 9263.938355449603},
#      {'class value': 4, 'sum': 58016.6913721122},
#      {'class value': 5, 'sum': 75276.69011311253}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '11',
#    'properties': {'SUBBASIN': 'FS_01',
#     'groups': [{'class value': 0, 'sum': 145809.6600750792},
#      {'class value': 1, 'sum': 383279.0218344296},
#      {'class value': 2, 'sum': 231390.08511906042},
#      {'class value': 4, 'sum': 292148.86851184315},
#      {'class value': 5, 'sum': 642300.0477578256}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '12',
#    'properties': {'SUBBASIN': 'JC_03',
#     'groups': [{'class value': 0, 'sum': 32975.92758899764},
#      {'class value': 1, 'sum': 89151.71350013881},
#      {'class value': 2, 'sum': 55911.67245193182},
#      {'class value': 4, 'sum': 96200.94375059838},
#      {'class value': 5, 'sum': 103396.03306923657}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '13',
#    'properties': {'SUBBASIN': 'FL_06',
#     'groups': [{'class value': 0, 'sum': 144714.8652090035},
#      {'class value': 1, 'sum': 564262.1596540271},
#      {'class value': 2, 'sum': 379107.3190374933},
#      {'class value': 4, 'sum': 414873.35596896894},
#      {'class value': 5, 'sum': 567642.6378510724}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '14',
#    'properties': {'SUBBASIN': 'WS_04',
#     'groups': [{'class value': 0, 'sum': 285930.4150757135},
#      {'class value': 1, 'sum': 346794.17343630333},
#      {'class value': 2, 'sum': 659960.0344694251},
#      {'class value': 3, 'sum': 40781.69427977918},
#      {'class value': 4, 'sum': 391278.7256952622},
#      {'class value': 5, 'sum': 533377.7225557815}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '15',
#    'properties': {'SUBBASIN': 'NT_10',
#     'groups': [{'class value': 0, 'sum': 157930.64149741377},
#      {'class value': 1, 'sum': 204027.76320723005},
#      {'class value': 2, 'sum': 68982.74991081089},
#      {'class value': 3, 'sum': 8189.481432716517},
#      {'class value': 4, 'sum': 237913.3167388617},
#      {'class value': 5, 'sum': 373593.4549188948}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '16',
#    'properties': {'SUBBASIN': 'NE_04',
#     'groups': [{'class value': 0, 'sum': 1768656.0448832498},
#      {'class value': 1, 'sum': 752853.7509626797},
#      {'class value': 2, 'sum': 703697.5430864822},
#      {'class value': 3, 'sum': 24636.64610395244},
#      {'class value': 4, 'sum': 470786.89507694636},
#      {'class value': 5, 'sum': 833852.3660144584}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '17',
#    'properties': {'SUBBASIN': 'LC_01',
#     'groups': [{'class value': 0, 'sum': 226606.8910764507},
#      {'class value': 1, 'sum': 304709.90408241434},
#      {'class value': 2, 'sum': 463000.66189724783},
#      {'class value': 3, 'sum': 5501.3586349487305},
#      {'class value': 4, 'sum': 308809.8671539905},
#      {'class value': 5, 'sum': 709557.9376090857}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '18',
#    'properties': {'SUBBASIN': 'NE_01',
#     'groups': [{'class value': 0, 'sum': 204104.5562039244},
#      {'class value': 1, 'sum': 155257.7293171602},
#      {'class value': 2, 'sum': 218191.31713717594},
#      {'class value': 3, 'sum': 974.7669212490903},
#      {'class value': 4, 'sum': 159279.625752707},
#      {'class value': 5, 'sum': 185578.4234293918}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '19',
#    'properties': {'SUBBASIN': 'NT_04',
#     'groups': [{'class value': 0, 'sum': 409223.0495685354},
#      {'class value': 1, 'sum': 77660.14219165876},
#      {'class value': 2, 'sum': 87279.39491119384},
#      {'class value': 3, 'sum': 36107.500392569746},
#      {'class value': 4, 'sum': 53263.92905988505},
#      {'class value': 5, 'sum': 111422.0121078192}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '20',
#    'properties': {'SUBBASIN': 'FS_03',
#     'groups': [{'class value': 0, 'sum': 191512.21794747742},
#      {'class value': 1, 'sum': 547341.5720260617},
#      {'class value': 2, 'sum': 587402.4355640488},
#      {'class value': 3, 'sum': 1834.1005020141602},
#      {'class value': 4, 'sum': 306772.40801433503},
#      {'class value': 5, 'sum': 852743.3993708607}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '21',
#    'properties': {'SUBBASIN': 'LP_03',
#     'groups': [{'class value': 0, 'sum': 75595.63052323285},
#      {'class value': 1, 'sum': 242842.51394979446},
#      {'class value': 2, 'sum': 263847.1769595875},
#      {'class value': 4, 'sum': 153606.87395815382},
#      {'class value': 5, 'sum': 282837.8160042556}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '22',
#    'properties': {'SUBBASIN': 'FS_05',
#     'groups': [{'class value': 0, 'sum': 59834.61213211359},
#      {'class value': 1, 'sum': 452785.70923856867},
#      {'class value': 2, 'sum': 90277.76286348829},
#      {'class value': 3, 'sum': 3267.1425106272986},
#      {'class value': 4, 'sum': 590796.6987440819},
#      {'class value': 5, 'sum': 1137732.7468445725}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '23',
#    'properties': {'SUBBASIN': 'NT_02',
#     'groups': [{'class value': 0, 'sum': 337783.47184552957},
#      {'class value': 1, 'sum': 895461.1097433955},
#      {'class value': 2, 'sum': 677767.7174409745},
#      {'class value': 3, 'sum': 32140.958728924925},
#      {'class value': 4, 'sum': 725565.586231366},
#      {'class value': 5, 'sum': 1318833.0558860926}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '24',
#    'properties': {'SUBBASIN': 'LP_01',
#     'groups': [{'class value': 0, 'sum': 131695.90588582357},
#      {'class value': 1, 'sum': 317823.3866151396},
#      {'class value': 2, 'sum': 108296.69641726624},
#      {'class value': 3, 'sum': 6812.679614586923},
#      {'class value': 4, 'sum': 196080.14084098669},
#      {'class value': 5, 'sum': 1258799.5303853652}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '25',
#    'properties': {'SUBBASIN': 'NT_07',
#     'groups': [{'class value': 0, 'sum': 585633.0119937072},
#      {'class value': 1, 'sum': 948543.6271839514},
#      {'class value': 2, 'sum': 607402.0022232654},
#      {'class value': 3, 'sum': 2779.1105476528987},
#      {'class value': 4, 'sum': 980100.4683596448},
#      {'class value': 5, 'sum': 1118274.1827585264}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '26',
#    'properties': {'SUBBASIN': 'TF_05',
#     'groups': [{'class value': 0, 'sum': 19495.86014404296},
#      {'class value': 1, 'sum': 192564.25915093516},
#      {'class value': 2, 'sum': 233066.7529799218},
#      {'class value': 3, 'sum': 16037.152461900898},
#      {'class value': 4, 'sum': 8173.943796494428},
#      {'class value': 5, 'sum': 700484.2624320537}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '27',
#    'properties': {'SUBBASIN': 'LC_04',
#     'groups': [{'class value': 0, 'sum': 120863.34702298032},
#      {'class value': 1, 'sum': 103402.98942939911},
#      {'class value': 2, 'sum': 117844.33905861051},
#      {'class value': 3, 'sum': 6046.535224914551},
#      {'class value': 4, 'sum': 77916.29135242538},
#      {'class value': 5, 'sum': 262861.8644886092}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '28',
#    'properties': {'SUBBASIN': 'FS_15',
#     'groups': [{'class value': 1, 'sum': 7330.995172119141},
#      {'class value': 2, 'sum': 704.3007121366613},
#      {'class value': 3, 'sum': 8490.32980439429},
#      {'class value': 4, 'sum': 48028.361206533395},
#      {'class value': 5, 'sum': 153361.91168951883}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '29',
#    'properties': {'SUBBASIN': 'FS_04',
#     'groups': [{'class value': 0, 'sum': 106711.64465442733},
#      {'class value': 1, 'sum': 246094.90128484994},
#      {'class value': 2, 'sum': 250716.75160962262},
#      {'class value': 4, 'sum': 241747.4943452424},
#      {'class value': 5, 'sum': 384578.7061357385}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '30',
#    'properties': {'SUBBASIN': 'NT_09',
#     'groups': [{'class value': 0, 'sum': 193459.70095511046},
#      {'class value': 1, 'sum': 108595.22852570776},
#      {'class value': 2, 'sum': 145220.88890964285},
#      {'class value': 3, 'sum': 19030.859549279307},
#      {'class value': 4, 'sum': 138597.67167765295},
#      {'class value': 5, 'sum': 197384.3966948865}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '31',
#    'properties': {'SUBBASIN': 'FL_07',
#     'groups': [{'class value': 0, 'sum': 369974.4030119652},
#      {'class value': 1, 'sum': 518485.8886413575},
#      {'class value': 2, 'sum': 439778.9851830578},
#      {'class value': 3, 'sum': 78998.30651855469},
#      {'class value': 4, 'sum': 354406.18363309366},
#      {'class value': 5, 'sum': 681024.8133370497}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '32',
#    'properties': {'SUBBASIN': 'NE_05',
#     'groups': [{'class value': 0, 'sum': 190595.1887408388},
#      {'class value': 1, 'sum': 238590.67346616255},
#      {'class value': 2, 'sum': 436886.7947362561},
#      {'class value': 3, 'sum': 15256.032712719487},
#      {'class value': 4, 'sum': 27548.360778718838},
#      {'class value': 5, 'sum': 275604.6171603032}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '33',
#    'properties': {'SUBBASIN': 'FS_13',
#     'groups': [{'class value': 0, 'sum': 339.62547302246094},
#      {'class value': 1, 'sum': 47329.21194452024},
#      {'class value': 3, 'sum': 2178.4883252312156},
#      {'class value': 4, 'sum': 104198.96273576326},
#      {'class value': 5, 'sum': 431012.85243380663}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '34',
#    'properties': {'SUBBASIN': 'LC_06',
#     'groups': [{'class value': 0, 'sum': 190836.92352163268},
#      {'class value': 1, 'sum': 45144.82786563051},
#      {'class value': 2, 'sum': 70403.59492271276},
#      {'class value': 4, 'sum': 38340.078745194965},
#      {'class value': 5, 'sum': 55102.424573561715}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '35',
#    'properties': {'SUBBASIN': 'LC_02',
#     'groups': [{'class value': 0, 'sum': 359808.1309650496},
#      {'class value': 1, 'sum': 766905.2038571525},
#      {'class value': 2, 'sum': 454118.67444787046},
#      {'class value': 4, 'sum': 692191.3650198843},
#      {'class value': 5, 'sum': 1224229.1692125208}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '36',
#    'properties': {'SUBBASIN': 'FS_14',
#     'groups': [{'class value': 0, 'sum': 2527.461288511987},
#      {'class value': 1, 'sum': 89956.1625771915},
#      {'class value': 2, 'sum': 67.91226196289062},
#      {'class value': 3, 'sum': 12715.763869850305},
#      {'class value': 4, 'sum': 107863.06167315315},
#      {'class value': 5, 'sum': 269969.7540637743}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '37',
#    'properties': {'SUBBASIN': 'FL_04',
#     'groups': [{'class value': 0, 'sum': 498795.7244438919},
#      {'class value': 1, 'sum': 732818.8694352988},
#      {'class value': 2, 'sum': 471560.1662308338},
#      {'class value': 4, 'sum': 618405.1223083196},
#      {'class value': 5, 'sum': 1154656.445509401}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '38',
#    'properties': {'SUBBASIN': 'FS_11',
#     'groups': [{'class value': 0, 'sum': 665037.4609041098},
#      {'class value': 1, 'sum': 897317.0999066802},
#      {'class value': 2, 'sum': 1427675.739856285},
#      {'class value': 4, 'sum': 723227.6726930798},
#      {'class value': 5, 'sum': 1095695.226804007}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '39',
#    'properties': {'SUBBASIN': 'NT_06',
#     'groups': [{'class value': 0, 'sum': 49457.82470604392},
#      {'class value': 1, 'sum': 35562.80464169373},
#      {'class value': 2, 'sum': 38683.00921807383},
#      {'class value': 3, 'sum': 8481.374160826439},
#      {'class value': 4, 'sum': 31762.948471907075},
#      {'class value': 5, 'sum': 58128.2810590258}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '40',
#    'properties': {'SUBBASIN': 'FL_05',
#     'groups': [{'class value': 0, 'sum': 91203.08896942137},
#      {'class value': 1, 'sum': 323764.63023158035},
#      {'class value': 2, 'sum': 242567.4102604584},
#      {'class value': 4, 'sum': 274414.1701914169},
#      {'class value': 5, 'sum': 644627.6279905129}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '41',
#    'properties': {'SUBBASIN': 'FL_02',
#     'groups': [{'class value': 0, 'sum': 696040.1118219113},
#      {'class value': 1, 'sum': 627691.3973336013},
#      {'class value': 2, 'sum': 971162.1004406192},
#      {'class value': 4, 'sum': 407862.96360318083},
#      {'class value': 5, 'sum': 1122282.82354123}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '42',
#    'properties': {'SUBBASIN': 'JC_02',
#     'groups': [{'class value': 0, 'sum': 212803.44992894182},
#      {'class value': 1, 'sum': 36328.74133142206},
#      {'class value': 2, 'sum': 60595.47210041122},
#      {'class value': 4, 'sum': 42316.435754813414},
#      {'class value': 5, 'sum': 42857.110877990744}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '43',
#    'properties': {'SUBBASIN': 'NE_06',
#     'groups': [{'class value': 0, 'sum': 4219.779718496285},
#      {'class value': 1, 'sum': 811680.6706110036},
#      {'class value': 2, 'sum': 162073.27933756507},
#      {'class value': 3, 'sum': 97484.90547021598},
#      {'class value': 4, 'sum': 138062.88904798919},
#      {'class value': 5, 'sum': 934640.0329425894}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '44',
#    'properties': {'SUBBASIN': 'FS_08',
#     'groups': [{'class value': 0, 'sum': 97259.91158869134},
#      {'class value': 1, 'sum': 338644.7485462863},
#      {'class value': 2, 'sum': 196743.5411287493},
#      {'class value': 4, 'sum': 168691.13478884238},
#      {'class value': 5, 'sum': 443196.3040442073}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '45',
#    'properties': {'SUBBASIN': 'TF_03',
#     'groups': [{'class value': 0, 'sum': 62486.750523466224},
#      {'class value': 1, 'sum': 344683.4571641511},
#      {'class value': 2, 'sum': 124965.78910390817},
#      {'class value': 3, 'sum': 69337.16852031036},
#      {'class value': 4, 'sum': 360539.61716527},
#      {'class value': 5, 'sum': 2940504.454176808}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '46',
#    'properties': {'SUBBASIN': 'LC_05',
#     'groups': [{'class value': 0, 'sum': 112378.75604672899},
#      {'class value': 1, 'sum': 170144.41619041297},
#      {'class value': 2, 'sum': 105420.24990500657},
#      {'class value': 4, 'sum': 112156.67293560551},
#      {'class value': 5, 'sum': 335547.25387444586}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '47',
#    'properties': {'SUBBASIN': 'LP_06',
#     'groups': [{'class value': 0, 'sum': 763953.2504225788},
#      {'class value': 1, 'sum': 69676.97255503335},
#      {'class value': 2, 'sum': 176540.89543834006},
#      {'class value': 4, 'sum': 24185.322381292604},
#      {'class value': 5, 'sum': 44409.18806304932}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '48',
#    'properties': {'SUBBASIN': 'FS_10',
#     'groups': [{'class value': 0, 'sum': 168834.19223728552},
#      {'class value': 1, 'sum': 827788.5212095378},
#      {'class value': 2, 'sum': 342908.23867103714},
#      {'class value': 4, 'sum': 500484.6152789845},
#      {'class value': 5, 'sum': 860263.4241160672}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '49',
#    'properties': {'SUBBASIN': 'JC_01',
#     'groups': [{'class value': 0, 'sum': 325042.2350011789},
#      {'class value': 1, 'sum': 134205.57145457558},
#      {'class value': 2, 'sum': 225996.27709661747},
#      {'class value': 4, 'sum': 171459.5946232216},
#      {'class value': 5, 'sum': 134284.99231815708}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '50',
#    'properties': {'SUBBASIN': 'LP_04',
#     'groups': [{'class value': 0, 'sum': 260040.29933085723},
#      {'class value': 1, 'sum': 436856.6741849119},
#      {'class value': 2, 'sum': 898074.6326798685},
#      {'class value': 4, 'sum': 381373.85677945},
#      {'class value': 5, 'sum': 611582.1167669864}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '51',
#    'properties': {'SUBBASIN': 'FL_09',
#     'groups': [{'class value': 0, 'sum': 611344.5470809636},
#      {'class value': 1, 'sum': 947944.2043423828},
#      {'class value': 2, 'sum': 1293250.631013548},
#      {'class value': 4, 'sum': 933064.8934988885},
#      {'class value': 5, 'sum': 1315343.0453148033}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '52',
#    'properties': {'SUBBASIN': 'TF_06',
#     'groups': [{'class value': 0, 'sum': 34684.89385402903},
#      {'class value': 1, 'sum': 220629.6123565974},
#      {'class value': 2, 'sum': 236170.49902717743},
#      {'class value': 3, 'sum': 116013.29239663515},
#      {'class value': 4, 'sum': 107194.35630921011},
#      {'class value': 5, 'sum': 934244.7914150758}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '53',
#    'properties': {'SUBBASIN': 'FS_12',
#     'groups': [{'class value': 0, 'sum': 46014.58861978563},
#      {'class value': 1, 'sum': 151888.20119892195},
#      {'class value': 2, 'sum': 38104.65265963685},
#      {'class value': 4, 'sum': 66859.10585440844},
#      {'class value': 5, 'sum': 243553.6455058679}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '54',
#    'properties': {'SUBBASIN': 'FS_09',
#     'groups': [{'class value': 0, 'sum': 130725.72379123459},
#      {'class value': 1, 'sum': 756759.7729028733},
#      {'class value': 2, 'sum': 218341.42885915723},
#      {'class value': 4, 'sum': 479990.2941268919},
#      {'class value': 5, 'sum': 756004.536091853}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '55',
#    'properties': {'SUBBASIN': 'NT_05',
#     'groups': [{'class value': 0, 'sum': 791634.8799029482},
#      {'class value': 1, 'sum': 1217154.5621210146},
#      {'class value': 2, 'sum': 1107557.6641597082},
#      {'class value': 3, 'sum': 4188.626374398026},
#      {'class value': 4, 'sum': 1099992.8215072332},
#      {'class value': 5, 'sum': 1715178.778033509}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '56',
#    'properties': {'SUBBASIN': 'FS_02',
#     'groups': [{'class value': 0, 'sum': 74870.18450006223},
#      {'class value': 1, 'sum': 220668.25623315547},
#      {'class value': 2, 'sum': 82295.99635054644},
#      {'class value': 4, 'sum': 431617.365029309},
#      {'class value': 5, 'sum': 979017.2369808416}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '57',
#    'properties': {'SUBBASIN': 'FS_06',
#     'groups': [{'class value': 0, 'sum': 11565.282352641985},
#      {'class value': 1, 'sum': 117824.89798506197},
#      {'class value': 2, 'sum': 69088.46411503808},
#      {'class value': 3, 'sum': 3230.1961361754175},
#      {'class value': 4, 'sum': 125068.85448704142},
#      {'class value': 5, 'sum': 344163.9966232898}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '58',
#    'properties': {'SUBBASIN': 'FS_07',
#     'groups': [{'class value': 0, 'sum': 16216.938730307185},
#      {'class value': 1, 'sum': 115113.5125155281},
#      {'class value': 2, 'sum': 51688.092102110604},
#      {'class value': 3, 'sum': 271.1670960968616},
#      {'class value': 4, 'sum': 142303.06181903917},
#      {'class value': 5, 'sum': 296717.280043718}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '59',
#    'properties': {'SUBBASIN': 'NT_11',
#     'groups': [{'class value': 0, 'sum': 89756.29872355743},
#      {'class value': 1, 'sum': 83256.45552206601},
#      {'class value': 2, 'sum': 10530.51809464997},
#      {'class value': 3, 'sum': 6572.629269857965},
#      {'class value': 4, 'sum': 141630.55089727667},
#      {'class value': 5, 'sum': 336593.79594110243}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '60',
#    'properties': {'SUBBASIN': 'LC_03',
#     'groups': [{'class value': 0, 'sum': 136523.82024224979},
#      {'class value': 1, 'sum': 91358.0503928988},
#      {'class value': 2, 'sum': 79542.91121221804},
#      {'class value': 4, 'sum': 27483.387555948895},
#      {'class value': 5, 'sum': 171025.9678485646}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '61',
#    'properties': {'SUBBASIN': 'NT_01',
#     'groups': [{'class value': 0, 'sum': 1275309.2072551653},
#      {'class value': 1, 'sum': 133676.36066945392},
#      {'class value': 2, 'sum': 105327.24228826784},
#      {'class value': 3, 'sum': 41049.07849788293},
#      {'class value': 4, 'sum': 28700.05097425872},
#      {'class value': 5, 'sum': 200939.69972549137}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '62',
#    'properties': {'SUBBASIN': 'LP_05',
#     'groups': [{'class value': 0, 'sum': 690434.5563792812},
#      {'class value': 1, 'sum': 363456.82344222727},
#      {'class value': 2, 'sum': 579251.4169842288},
#      {'class value': 4, 'sum': 326123.67987228086},
#      {'class value': 5, 'sum': 595680.0984272077}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '63',
#    'properties': {'SUBBASIN': 'FL_08',
#     'groups': [{'class value': 0, 'sum': 66145.63297382431},
#      {'class value': 1, 'sum': 189397.93845711497},
#      {'class value': 2, 'sum': 96219.25015375472},
#      {'class value': 4, 'sum': 183861.34402597463},
#      {'class value': 5, 'sum': 291272.95519675466}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '64',
#    'properties': {'SUBBASIN': 'FL_01',
#     'groups': [{'class value': 0, 'sum': 342296.7354385675},
#      {'class value': 1, 'sum': 370448.07712489116},
#      {'class value': 2, 'sum': 406140.4946240294},
#      {'class value': 4, 'sum': 359960.30109073425},
#      {'class value': 5, 'sum': 551357.4129797244}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '65',
#    'properties': {'SUBBASIN': 'TF_04',
#     'groups': [{'class value': 0, 'sum': 1753.3568979300703},
#      {'class value': 1, 'sum': 131455.85047706153},
#      {'class value': 2, 'sum': 65743.42318695667},
#      {'class value': 3, 'sum': 11722.799520096121},
#      {'class value': 4, 'sum': 107870.07734099744},
#      {'class value': 5, 'sum': 1414221.2409883686}]}},
#   {'type': 'Feature',
#    'geometry': None,
#    'id': '66',
#    'properties': {'SUBBASIN': 'FL_10',
#     'groups': [{'class value': 0, 'sum': 98011.7261458752},
#      {'class value': 1, 'sum': 93546.5673165116},
#      {'class value': 2, 'sum': 40622.635472256516},
#      {'class value': 3, 'sum': 14621.140655517578},
#      {'class value': 4, 'sum': 129835.8824823417},
#      {'class value': 5, 'sum': 244602.70583546965}]}}]}

# %%
# Normalize the "groups" property into a DataFrame
df = pd.json_normalize(data, record_path='features', 
                       #record_prefix='properties.'
                       errors='ignore')

class_df = pd.DataFrame()
for i in range(df.shape[0]):
    groups = df.loc[i, 'properties.groups']
    temp_df = pd.json_normalize(groups)
    temp_df = temp_df.set_index('class value').T
    temp_df.index = [i]
    class_df = pd.concat([class_df, temp_df], axis=0, sort=False)


# Merge the class DataFrame with the original DataFrame
df = pd.merge(df, class_df, left_index=True, right_index=True)

# Drop unnecessary columns
df = df.drop(columns=['geometry', 'properties.groups'])

new_cols = {
    0:  "Forest/Trees",
    1: "Pasture",
    2: "Grass",
    3: "Water",
    4: "Impervious-roof",
    5: "Impervious-nonRoof"
}
df_named = df.rename(columns=new_cols).drop(['id','type'], axis=1)

# %%
df_named
# Out:
#    properties.SUBBASIN  Forest/Trees       Pasture         Grass  \
# 0                WS_03  4.037025e+05  5.524089e+05  5.172937e+05
# 1                WS_01  1.805662e+06  3.346572e+05  2.931161e+05
# 2                FL_03  7.500343e+05  1.261949e+06  1.431501e+06
# 3                TF_01  5.131472e+03  2.640801e+05  5.221681e+04
# 4                NE_03  1.158250e+06  5.655599e+05  1.001179e+06
# ..                 ...           ...           ...           ...
# 62               LP_05  6.904346e+05  3.634568e+05  5.792514e+05
# 63               FL_08  6.614563e+04  1.893979e+05  9.621925e+04
# 64               FL_01  3.422967e+05  3.704481e+05  4.061405e+05
# 65               TF_04  1.753357e+03  1.314559e+05  6.574342e+04
# 66               FL_10  9.801173e+04  9.354657e+04  4.062264e+04
#
#            Water  Impervious-roof  Impervious-nonRoof
# 0   44620.252467     4.527086e+05        7.942077e+05
# 1   43867.260185     2.320297e+05        3.867151e+05
# 2    8193.493945     1.063263e+06        2.349192e+06
# 3   91419.085543     1.970301e+05        4.381448e+05
# 4   60787.184197     5.687487e+05        6.035520e+05
# ..           ...              ...                 ...
# 62           NaN     3.261237e+05        5.956801e+05
# 63           NaN     1.838613e+05        2.912730e+05
# 64           NaN     3.599603e+05        5.513574e+05
# 65  11722.799520     1.078701e+05        1.414221e+06
# 66  14621.140656     1.298359e+05        2.446027e+05
#
# [67 rows x 7 columns]

# %%
df_named

# calculate the total area for each row
total_area = df_named.sum(axis=1)

# divide each land cover type by the total area to get the percentage
df_percent = df_named.iloc[:, 1:].div(total_area, axis=0) 

# concatenate the ID column with the percentage columns
df_percent.insert(0, 'SUBBASIN', df['properties.SUBBASIN'])

# print the resulting DataFrame
df_percent.to_csv('exported_data/landcover.csv')
# Out:
# /var/folders/yn/15903z7124l3th5fm7wg0lgw0000gn/T/ipykernel_20496/3915731589.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   total_area = df_named.sum(axis=1)

# %% [markdown]
# # Habitat
# Tree Canopy % Cover in buffers (varies for stream type)

# %% [markdown]
# Biodiversity Cooridor
# 150-foot Buffer % vegetated
# 75-foot Buffer % vegetated
# 25-foot Buffer % vegetated

# %% [markdown]
# # Water Quality
# 303d (listing)
# TMDL (y/n)

# %%
attains_url = 'https://gispub.epa.gov/arcgis/rest/services/OW/ATTAINS_Assessment/MapServer/1'

# %%
feature = subbasins.iloc[0]
geom = list(feature.geometry.exterior.coords)
coord_strings = [f"{x}, {y}" for x, y in geom]
coord_strings
# Out:
# ['-122.52683047424546, 47.25504204954043',
#  '-122.52698273419371, 47.25520835004718',
#  '-122.52708039055457, 47.25547499482117',
#  '-122.52704599948555, 47.25572407325478',
#  '-122.52687955918285, 47.25595558523543',
#  '-122.5265077489281, 47.25616087123752',
#  '-122.52616811234994, 47.25644510653198',
#  '-122.52616251954599, 47.25668374170972',
#  '-122.52627663791104, 47.25699979519835',
#  '-122.52647979210587, 47.25735404711795',
#  '-122.52672296723276, 47.25760820790029',
#  '-122.5268056624389, 47.257865176337695',
#  '-122.52693175153361, 47.25811144632104',
#  '-122.52692353700667, 47.25828055395407',
#  '-122.52663812281496, 47.25845451182343',
#  '-122.52656220874924, 47.25876394963658',
#  '-122.52648216980856, 47.25896413178532',
#  '-122.52638754055458, 47.25916456729309',
#  '-122.52638419787321, 47.259462798058664',
#  '-122.5264040603891, 47.259881035010714',
#  '-122.52639758198893, 47.260607355313056',
#  '-122.5263969458543, 47.26067877799427',
#  '-122.526393628453, 47.26105079332399',
#  '-122.52652582311158, 47.26105134027017',
#  '-122.5265194038958, 47.26177116998828',
#  '-122.52683216545742, 47.26311013853395',
#  '-122.52688378879667, 47.26354199353349',
#  '-122.52690374657537, 47.2640705724654',
#  '-122.52685039339715, 47.26452830627275',
#  '-122.52639518076363, 47.26463243877691',
#  '-122.52593633931595, 47.264640463903746',
#  '-122.5252240859652, 47.26448462185107',
#  '-122.52461137859908, 47.264158741862936',
#  '-122.52351632347914, 47.26415383240654',
#  '-122.5225307754295, 47.264243169726164',
#  '-122.522112662346, 47.264394721151696',
#  '-122.52158321071053, 47.26443911070141',
#  '-122.52158040675945, 47.26443934588689',
#  '-122.52145745962017, 47.264449653241925',
#  '-122.52203889024698, 47.264652063915655',
#  '-122.52273051799662, 47.26519311141935',
#  '-122.52317230046859, 47.26566637197085',
#  '-122.52382774072058, 47.26618399657965',
#  '-122.52468959200846, 47.26655371748478',
#  '-122.5251814287988, 47.26666681210312',
#  '-122.5252576410148, 47.266250905188194',
#  '-122.52585645858319, 47.26596377413237',
#  '-122.52670210016849, 47.265755320947235',
#  '-122.5278372699222, 47.26568012506204',
#  '-122.52881206208212, 47.26566305813029',
#  '-122.5296670944429, 47.265703412647824',
#  '-122.53039923622083, 47.26571824902754',
#  '-122.53084810721768, 47.26576571440535',
#  '-122.53150215482621, 47.26586491088114',
#  '-122.53228223964584, 47.26607255750534',
#  '-122.53261135950294, 47.26617744824147',
#  '-122.53306233185427, 47.266280199737395',
#  '-122.53363096629477, 47.26627021938152',
#  '-122.53427454762186, 47.26609292394637',
#  '-122.5347952276385, 47.26589011600873',
#  '-122.53540237684328, 47.26582411887567',
#  '-122.53601162181371, 47.26581341323512',
#  '-122.5367927723942, 47.2660486777321',
#  '-122.53760720222823, 47.26608968770436',
#  '-122.53838416565874, 47.26621435125335',
#  '-122.53923921395217, 47.266254634231096',
#  '-122.53997136463326, 47.26626941194895',
#  '-122.5408327218997, 47.26647557143547',
#  '-122.5414910024975, 47.26668530154184',
#  '-122.54160822140715, 47.26673081132911',
#  '-122.54220249916244, 47.266961531798536',
#  '-122.54245196104985, 47.26668035987564',
#  '-122.54390796193107, 47.26538136020782',
#  '-122.54416996214826, 47.26507536085114',
#  '-122.5446669611414, 47.26449436026234',
#  '-122.54515482188495, 47.26395688847109',
#  '-122.54519096230219, 47.26391736057435',
#  '-122.54552696225463, 47.263547360116625',
#  '-122.54660996104536, 47.26188235993908',
#  '-122.54706396133002, 47.261320360236546',
#  '-122.54742296241993, 47.2608463601062',
#  '-122.54764796196964, 47.26048836051245',
#  '-122.54794496153671, 47.260014360263874',
#  '-122.54837096175103, 47.25947936015688',
#  '-122.54869596141089, 47.25901236042253',
#  '-122.54927196189419, 47.25809836008236',
#  '-122.54989496184068, 47.25697536056837',
#  '-122.55024696204855, 47.2563933607842',
#  '-122.55041496207392, 47.256156360147266',
#  '-122.55057196180958, 47.25593236075051',
#  '-122.55238696124037, 47.25438936055473',
#  '-122.5525839626427, 47.25413236001482',
#  '-122.55285496154846, 47.2536313607168',
#  '-122.55304396241107, 47.25309036048033',
#  '-122.55324096219536, 47.25260236087297',
#  '-122.55326796253603, 47.25228436087422',
#  '-122.55244113530921, 47.25224364976102',
#  '-122.55158735522193, 47.252231110450055',
#  '-122.5508575061358, 47.252271702514726',
#  '-122.55000900389803, 47.25239739009342',
#  '-122.54900334941442, 47.25266418273165',
#  '-122.54808838825545, 47.25317836131848',
#  '-122.5474481715201, 47.25343867821686',
#  '-122.54684539176452, 47.25361533007288',
#  '-122.54649257427063, 47.253953561883776',
#  '-122.5460616991757, 47.2543761693704',
#  '-122.54525270634689, 47.25447345550804',
#  '-122.54491836853651, 47.25423036242021',
#  '-122.54503516123549, 47.25397195166983',
#  '-122.5450191294683, 47.25367525582926',
#  '-122.54498870858846, 47.253492743284795',
#  '-122.54500373515629, 47.25314685612251',
#  '-122.54514891165947, 47.25281530801339',
#  '-122.54514154002122, 47.25262177356735',
#  '-122.5449621970694, 47.25263607520422',
#  '-122.5446959235316, 47.252657307337124',
#  '-122.54388379815833, 47.25267164176522',
#  '-122.54294985370743, 47.25268811931442',
#  '-122.54234706761505, 47.25286474871407',
#  '-122.54158395452434, 47.25309953389547',
#  '-122.54102176817558, 47.25327543965525',
#  '-122.54050438740514, 47.25356121880323',
#  '-122.54001815223016, 47.25359744996782',
#  '-122.53944545380922, 47.25349687105105',
#  '-122.53907264071142, 47.25330977091085',
#  '-122.5384166340689, 47.253155320871905',
#  '-122.53780228522791, 47.25302779925882',
#  '-122.53711092315409, 47.25301229534833',
#  '-122.53649133717855, 47.252746527631984',
#  '-122.53611015213617, 47.252338236314564',
#  '-122.5360517223478, 47.25186893579696',
#  '-122.53594849670678, 47.25128975807952',
#  '-122.53584632028996, 47.250738229462435',
#  '-122.53566922690094, 47.25035401307183',
#  '-122.53520685480201, 47.249947144913044',
#  '-122.53471017344647, 47.2497068750995',
#  '-122.53412495813778, 47.249274494077504',
#  '-122.53366365547613, 47.24889526800167',
#  '-122.53316803761705, 47.24868263991874',
#  '-122.53258598548905, 47.248333194496205',
#  '-122.53240275672287, 47.248317278786395',
#  '-122.5323405010011, 47.24831187121231',
#  '-122.5320560508543, 47.248287161360075',
#  '-122.53140448856504, 47.24829483899696',
#  '-122.53140336350677, 47.24839336257619',
#  '-122.53087003029769, 47.24837173830529',
#  '-122.53043242936556, 47.24837941125737',
#  '-122.52999482830846, 47.248387082556306',
#  '-122.52973226761412, 47.24839168454212',
#  '-122.5293818112075, 47.24838788617879',
#  '-122.5291675146327, 47.2485109102898',
#  '-122.5288526107639, 47.248675452893025',
#  '-122.5285956770656, 47.24882904009938',
#  '-122.5283519588238, 47.248911051713705',
#  '-122.5282198522001, 47.248910507629326',
#  '-122.5275004216624, 47.24900969520933',
#  '-122.52687345207133, 47.24923705041057',
#  '-122.52624375592622, 47.249392322621716',
#  '-122.52608001993237, 47.24973177978985',
#  '-122.5260203268125, 47.25002133093634',
#  '-122.52635331324407, 47.25042422415211',
#  '-122.52654425312133, 47.25080555964589',
#  '-122.52687833380874, 47.25115455282358',
#  '-122.5267299876242, 47.253860540789525',
#  '-122.52672927305566, 47.253873575038114',
#  '-122.52664897179692, 47.25410101520592',
#  '-122.52672044724486, 47.25444763185819',
#  '-122.52678292499711, 47.254555867420216',
#  '-122.52681847586716, 47.25472420943429',
#  '-122.52682335022514, 47.254853332881396',
#  '-122.52683047424546, 47.25504204954043']

# %%
tacoma_bbox ="-122.66645777315975, 47.066727220416695, -122.24485743136287, 47.353125316075044"

# %%
# From 
# https://gis.stackexchange.com/questions/427434/query-feature-service-on-esri-arcgis-rest-api-with-python-requests
import urllib.parse

attains_url = 'https://gispub.epa.gov/arcgis/rest/services/OW/ATTAINS_Assessment/MapServer/1/query?'

params = {
    'geometry':tacoma_bbox,
    'geometryType': 'esriGeometryEnvelope',
    'inSR': '4326',
    'returnGeometry': 'true', 
    'outFields': 'assessmentunitidentifier,assessmentunitname,tas303d,reportingcycle,waterbodyreportlink,ircategory',
    'f': 'geojson'
}

url_final = attains_url + urllib.parse.urlencode(params)
url_final
# Out:
# 'https://gispub.epa.gov/arcgis/rest/services/OW/ATTAINS_Assessment/MapServer/1/query?geometry=-122.66645777315975%2C+47.066727220416695%2C+-122.24485743136287%2C+47.353125316075044&geometryType=esriGeometryEnvelope&inSR=4326&returnGeometry=true&outFields=assessmentunitidentifier%2Cassessmentunitname%2Ctas303d%2Creportingcycle%2Cwaterbodyreportlink%2Circategory&f=geojson'

# %%
 wq_lines = gp.read_file(url_final,driver="GeoJSON")

# %%
#get intersecting water quality lines 

water_quality = gp.overlay(wq_lines, subbasins, how='intersection')

# %%
gdf_no_geom = water_quality.drop(columns='geometry')

# Save as CSV without geometry column
gdf_no_geom.to_csv('exported_data/waterquality.csv', index=False)

# %% [markdown]
# # of discharge points (Outfalls)
# # of Ditches
# # of Culvert Crossings

# %%
ditches = "33"

# %%
discharge_pts_path = "ES/SurfacewaterNetwork/MapServer/24"
ditches_path = "ES/SurfacewaterNetwork/MapServer/30"

# %%
discharge_pts_path = "ES/SurfacewaterNetwork/MapServer/24" 
discharge_pts = get_geojson_as_gp(base_url,discharge_pts_path)
ditches = get_geojson_as_gp(base_url,ditches_path)

# %%
urban_heat = "https://gis.cityoftacoma.org/arcgis/rest/services/ES/UrbanHeatIslandIndex/MapServer/0"
subbasins.head
# Out:
# <bound method NDFrame.head of            BASINNAME SUBBASIN  \
# 0     WESTERN SLOPES    WS_03
# 1     WESTERN SLOPES    WS_01
# 2        FLETT CREEK    FL_03
# 3          TIDEFLATS    TF_01
# 4   NORTHEAST TACOMA    NE_03
# ..               ...      ...
# 62    LOWER PUYALLUP    LP_05
# 63       FLETT CREEK    FL_08
# 64       FLETT CREEK    FL_01
# 65         TIDEFLATS    TF_04
# 66       FLETT CREEK    FL_10
#
#                                              geometry
# 0   POLYGON ((-122.52683 47.25504, -122.52698 47.2...
# 1   POLYGON ((-122.51714 47.27441, -122.51758 47.2...
# 2   POLYGON ((-122.47503 47.20173, -122.47490 47.2...
# 3   POLYGON ((-122.42198 47.26224, -122.42210 47.2...
# 4   POLYGON ((-122.38348 47.29529, -122.38389 47.2...
# ..                                                ...
# 62  POLYGON ((-122.39694 47.22092, -122.39714 47.2...
# 63  POLYGON ((-122.45568 47.18457, -122.45606 47.1...
# 64  POLYGON ((-122.49178 47.25034, -122.49200 47.2...
# 65  POLYGON ((-122.37710 47.25412, -122.38171 47.2...
# 66  POLYGON ((-122.45933 47.17371, -122.46021 47.1...
#
# [67 rows x 3 columns]>

# %%
# Group by the boundary name and count the number of facilities
discharge_pt_count = discharge_pts.groupby('SUBBASIN').size().reset_index(name='facility_count')
ditches_count = ditches.groupby('SUBBASIN').size().reset_index(name='ditches_count')
ditches_count.to_csv('exported_data/ditches.csv')
discharge_pt_count.to_csv('exported_data/discharge_pts.csv')
